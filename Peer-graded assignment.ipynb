# %% [markdown]
# My Jupyter Notebook

# %% [markdown]
# This is an introduction to commonly used data science tools.

# %% [markdown]
# - Most commonly used data science languages by data scientists across the globe are Python, R, and SQL.   <br>
# - Languages such as php, Scala, C++, and JUlia are also a preferred choice for data scientists for what they can offer.    <br>
# - Other languages such as JavaScript, RUby, and Visual Basics are sometimees used.

# %% [markdown]
# Popular data science libraries
# - In python programming language include Pandas, NumPy, SciPy, ad Matplotlib
# - In R includes Ggplot2 and Dplyr
# - In SQL databases like MySQL, MariaDB, Oracle, etc.

# %% [markdown]
# |       Data Science tools       |
# | ------------------------------ |
# | Matplotlib | Jupyter | RStudio |
# |   Python   |  Excel  |  Knime  |
# | TensorFlow | Tableau |  Hadoop |

# %% [markdown]
# Addition and multiplication operration adds and multipies two numbers respectively.

# %%
a = 2 + 2
b = 2*3
print("Add:",a)
print("Multiply:",b)
# Out:
# Add: 4
# Multiply: 6

# %% [markdown]
# Conversion of minutes to hrs

# %%
min = 45
hrs = min/60
print(hrs)
# Out:
# 0.75

# %% [markdown]
# The objective of this assignment is to
# - Get familiar with Jupyter notebooks
# - Perform basic arithmetic operations inn Jupyter notebook
# - Learn how to create code cells and markdown cells

# %% [markdown]
# Created by:   <br>
# Munish BOthlikar     <br>
# Student at Corsera
