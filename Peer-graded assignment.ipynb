# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# *This is an introduction to commonly used data science tools.*

# %% [markdown]
# #### Most commonly used data science languages by data scientists across the globe are
#     1. Python
#     2. R
#     3. SQL
#     4. Java
#     5. C++
#     6. Julia, etc.

# %% [markdown]
# #### Popular data science libraries
#     1. Pandas
#     2. NumPy
#     3. SciPy
#     4. Matplotlib
#     5. Ggplot2

# %% [markdown]
# #### Data Science tools include
# | Data Science tools|
# | ----------------- |
# | Jupyter |
# | RStudio |
# | TensorFlow |
# | Tableau |
# | Hadoop |
# | SPSS Modeler |

# %% [markdown]
# #### Addition and multiplication operration adds and multipies two numbers respectively.

# %%
a = 2 + 2
b = 2*3
print("Add:",a)
print("Multiply:",b)
# Out:
# Add: 4
# Multiply: 6

# %% [markdown]
# #### Conversion of minutes to hrs

# %%
min = 45
hrs = min/60
print(hrs)
# Out:
# 0.75

# %% [markdown]
# #### The objective of this assignment is to
# 1. Get familiar with Jupyter notebooks
# 2. Perform basic arithmetic operations inn Jupyter notebook
# 3. Learn how to create code cells and markdown cells

# %% [markdown]
# ### Created by:   <br>
# Munish BOthlikar     <br>
# *Student at Corsera*
